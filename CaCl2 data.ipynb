# %%
import plotly.express as px
import numpy as np
import pandas as pd
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# # data

# %%
pur_wash_data=[
['P111',	1.03,	2,	2.2,	2.11,	2.6,	0.8333,	0.08,	0.1,	0.041,	8.9,],
['P112',	1.039,	2,	2.2,	20.8,	1.5,	0.8315,	0.1,	0.29,	0.01,	8.35,],
['P113',	1.083,	2,	2.2,	39.6,	1,	0.8231,	0.13,	0.62,	0.022,	7.45,],
['P114',	1.123,	2.2,	2.2,	60.4,	0.68,	0.8281,	0.13,	1.1,	0.046,	6.75,],
['P121',	1.015,	1.95,	30.4,	2.06,	2.4,	0.8373,	0.15,	2.92,	0.075,	9.5,],
['P122',	1.082,	2.04,	29.6,	20.2,	1.7,	0.8358,	0.15,	6.1,	0.033,	9.5,],
['P123',	1.094,	2.04,	31.4,	37.2,	1.2,	0.8404,	0.25,	9.7,	0.067,	9.3,],
['P124',	1.135,	2.03,	30,	58.4,	0.8,	0.8386,	0.23,	17.8,	0.13,	9.6,],
['P131',	1.027,	2.1,	60.8,	2.1,	2.2,	0.8398,	0.25,	9.7,	0.042,	10.8,],
['P132',	1.066,	2.2,	60.7,	19.8,	1.7,	0.8419,	0.31,	15.5,	0.056,	11.2,],
['P133',	1.105,	2,	59.2,	38.2,	1.2,	0.8542,	0.43,	22.6,	0.1,	11.6,],
['P134',	1.154,	1.96,	60.5,	61.6,	0.93,	0.8587,	0.68,	35.1,	0.25,	12.9,],
['P141',	1.041,	2,	87.6,	2,	2.4,	0.8512,	0.36,	21.7,	0.028,	13,],
['P142',	1.11,	1.96,	90.2,	20.3,	1.8,	0.8597,	0.45,	30.4,	0.11,	13.9,],
['P143',	1.117,	2.1,	90.8,	41,	1.4,	0.871,	0.65,	39.1,	0.25,	14.2,],
['P144',	1.157,	2.1,	91,	60,	1.1,	0.8796,	0.9,	49.9,	0.35,	15.3,],
['P211',	1.057,	81.2,	2.1,	2.2,	1.9,	0.8407,	4.4,	0.11,	0.034,	9.3,],
['P212',	1.097,	79.5,	2.59,	19,	1.3,	0.8321,	4.6,	1.65,	0.025,	8.2,],
['P213',	1.14,	80.8,	1.9,	40.8,	1,	0.8374,	7.6,	3.76,	0.16,	7.8,],
['P214',	1.218,	79.7,	2.6,	60.8,	0.73,	0.8424,	11,	6.8,	0.24,	7.5,],
['P221',	1.068,	80.9,	30.8,	2,	1.9,	0.8456,	7,	4.1,	0.042,	9.5,],
['P222',	1.105,	81.6,	29.8,	20,	1.4,	0.8471,	9.87,	8.4,	0.036,	9.7,],
['P223',	1.148,	79.5,	29.6,	40.4,	1.1,	0.8576,	15.9,	16.1,	0.18,	10.3,],
['P224',	1.187,	80.7,	33.5,	57.6,	0.76,	0.8647,	21.4,	22.2,	0.31,	11.2,],
['P231',	1.08,	81.6,	59,	2.04,	1.9,	0.8479,	11.4,	14.2,	0.017,	11.3,],
['P232',	1.117,	82,	62.2,	20,	1.5,	0.8591,	16,	20.7,	0.062,	12.1,],
['P233',	1.158,	82.3,	61.7,	41.6,	1.2,	0.8837,	22.3,	31.2,	0.23,	12.5,],
['P234',	1.198,	82,	60.8,	60,	0.96,	0.887,	30.2,	40,	0.44,	13.1,],
['P241',	1.192,	80.7,	89.7,	2,	2.1,	0.8764,	17.7,	26,	0.026,	14,],
['P242',	1.163,	81.8,	90.8,	20.3,	1.9,	0.8841,	23.3,	39.1,	0.2,	14.7,],
['P243',	1.172,	78.9,	89.4,	40.4,	1.3,	0.8937,	30.4,	49,	0.4,	15.1,],
['P244',	1.208,	80,	90.6,	57.6,	0.97,	0.9135,	37.2,	59.7,	0.6,	15.6,],
['P311',	1.147,	161.6,	1.6,	2.04,	1.6,	0.8408,	11.9,	0.47,	0.092,	8.3,],
['P312',	1.152,	162.4,	2.1,	20,	1.2,	0.845,	15.6,	3.1,	0.068,	8.8,],
['P313',	1.189,	161.6,	2.5,	39.2,	0.95,	0.8578,	22.8,	7.3,	0.13,	8.9,],
['P314',	1.229,	162,	2.56,	57.6,	0.66,	0.8728,	34.4,	13.3,	0.43,	9.1,],
['P321',	1.125,	162.4,	29.7,	2,	1.7,	0.8644,	20.2,	7.1,	0.017,	9.7,],
['P322',	1.161,	162.9,	34,	20,	1.3,	0.8615,	28.8,	14,	0.081,	10.8,],
['P323',	1.201,	160,	33.8,	38,	1.1,	0.8796,	39.4,	21.4,	0.32,	11.3,],
['P324',	1.238,	162.7,	30.2,	57.6,	0.88,	0.8999,	50,	29.8,	0.63,	11.1,],
['P331',	1.136,	163,	59.3,	2,	1.9,	0.8839,	32.4,	20.2,	0.022,	12.6,],
['P332',	1.17,	162.9,	59.3,	21,	1.5,	0.8946,	42.4,	27.7,	0.084,	13.3,],
['P333',	1.21,	162.9,	59.7,	40.8,	1.1,	0.9118,	54,	37.8,	0.44,	13.6,],
['P334',	1.253,	161.6,	60.7,	60.8,	0.91,	0.9254,	67.7,	50.2,	0.9,	13.3,],
['P341',	1.15,	161.3,	90.8,	2.2,	1.9,	0.9051,	45,	36.4,	0.026,	15.2,],
['P342',	1.185,	161.2,	90.2,	20.2,	1.8,	0.9156,	55.6,	47.5,	0.36,	15.4,],
['P343',	1.222,	162.4,	87.7,	40.4,	1.2,	0.9256,	65,	54.8,	0.67,	15.8,],
['P344',	1.298,	158.4,	88.3,	61,	0.96,	0.9402,	74.5,	67.9,	1.15,	15.4,],
['P411',	1.174,	240.5,	2.3,	2.02,	1.3,	0.8511,	26.7,	0.88,	0.1,	8.5,],
['P412',	1.206,	242.4,	2.7,	19.2,	1.1,	0.8771,	35.7,	7.6,	0.088,	9.3,],
['P413',	1.246,	242.2,	2.15,	37.6,	0.9,	0.8847,	52.1,	13.8,	0.35,	10,],
['P414',	1.282,	241.1,	2.7,	59.6,	0.68,	0.9005,	65.9,	20.2,	0.92,	10.1,],
['P421',	1.179,	240,	28.8,	2.04,	0.79,	0.883,	44.6,	9.9,	0.024,	11,],
['P422',	1.218,	243.7,	30.2,	19.6,	1.2,	0.8979,	57.6,	20,	0.2,	11.7,],
['P423',	1.253,	241.6,	31.3,	38.4,	0.98,	0.9179,	71.1,	28.5,	0.6,	11.7,],
['P424',	1.29,	242.1,	29.2,	57.6,	0.99,	0.9307,	86.6,	35.7,	1.15,	12,],
['P431',	1.189,	240.8,	62.4,	2.1,	1.7,	0.9053,	64.1,	25.8,	0.039,	14.3,],
['P432',	1.259,	241.9,	56.2,	19.7,	1.4,	0.9218,	75.3,	33.9,	0.35,	13.9,],
['P433',	1.263,	240,	57.3,	39.6,	1.2,	0.9383,	92.2,	46.7,	0.83,	13.9,],
['P434',	1.3,	241.1,	60.4,	59.2,	0.89,	0.9548,	98.7,	47.1,	1.72,	13.5,],
['P441',	1.202,	238,	91.2,	2.06,	1.9,	0.9355,	80.5,	46.2,	0.075,	16.4,],
['P442',	1.236,	240,	89.8,	19.2,	1.4,	0.9546,	91.4,	52.7,	0.53,	15.9,],
['P443',	1.273,	240.5,	89.2,	39.2,	1.2,	0.9659,	99.7,	62.6,	0.97,	15.5,],
['P444',	1.308,	238.7,	88.3,	58.4,	1.5,	0.9766,	110.7,	70.6,	1.88,	15.2,],
['REF1',	1.161,	121.4,	44.2,	28.4,	1.3,	0.8736,	27.3,	22.2,	0.23,	11.6,],
['REF2',	1.159,	120.7,	44.9,	30,	1.3,	0.871,	26.7,	21,	0.2,	11.4,],
]

# %%
extr_data=[
['E111',	1.179,	2,	2.15,	86.1,	0.43,	0.8244,	0.19,	2.46,	0.12,	5.6,],
['E112',	1.207,	2,	2.1,	100.7,	0.33,	0.8263,	0.25,	3.45,	0.21,	5.45,],
['E113',	1.236,	2,	2.1,	116,	0.26,	0.8292,	0.37,	5.4,	0.36,	5.2,],
['E114',	1.265,	2,	2,	131.2,	0.18,	0.8302,	0.59,	8.1,	0.56,	5.2,],
['E121',	1.18,	2,	11.2,	86.4,	0.43,	0.8342,	0.38,	10,	0.18,	7.4,],
['E122',	1.209,	2,	11.2,	100.8,	0.38,	0.8401,	0.58,	15.2,	0.25,	7.3,],
['E123',	1.24,	2,	11,	116,	0.24,	0.8414,	0.85,	20.6,	0.38,	7.8,],
['E124',	1.268,	2,	11.1,	131.2,	0.24,	0.8459,	1.18,	26.2,	0.55,	7.8,],
['E131',	1.185,	2,	20.4,	85.6,	0.47,	0.8427,	0.57,	17.8,	0.24,	8.7,],
['E132',	1.213,	2,	20.4,	101.6,	0.39,	0.8443,	0.76,	23.7,	0.26,	9.2,],
['E133',	1.243,	2,	20.3,	115.2,	0.33,	0.8496,	1.1,	30.4,	0.42,	9.3,],
['E134',	1.273,	2,	20,	131.2,	0.27,	0.8555,	1.4,	37.8,	0.56,	9.8,],
['E141',	1.187,	2,	29.7,	85.8,	0.49,	0.8475,	0.65,	24.9,	0.27,	9.9,],
['E142',	1.217,	2,	29,	102.4,	0.43,	0.8496,	0.9,	31.6,	0.33,	10.1,],
['E143',	1.248,	2,	29.4,	116,	0.27,	0.8559,	1.24,	39.9,	0.22,	10.6,],
['E144',	1.276,	2,	29.2,	131.2,	0.21,	0.8661,	1.73,	47.7,	0.55,	10.8,],
['E211',	1.203,	45.8,	3.1,	86,	0.5,	0.8446,	8.2,	7.7,	0.28,	6.6,],
['E212',	1.235,	45.2,	2.5,	100.8,	0.33,	0.8432,	10.3,	10.8,	0.58,	6.8,],
['E213',	1.263,	46,	2.1,	115.5,	0.25,	0.8496,	15.6,	15.4,	0.76,	6.9,],
['E214',	1.291,	46.1,	2.7,	129.6,	0.21,	0.8594,	21.3,	20.2,	1.38,	7,],
['E221',	1.208,	45.8,	11.8,	85.8,	0.52,	0.8459,	11.3,	14.7,	0.34,	8.7,],
['E222',	1.237,	46.3,	11.9,	100,	0.39,	0.8547,	15.8,	20.4,	0.58,	8.3,],
['E223',	1.267,	46.5,	12,	115.2,	0.27,	0.8643,	21.1,	25.6,	0.91,	8.2,],
['E224',	1.299,	45.1,	11.6,	131.2,	0.22,	0.8724,	25.8,	31.9,	1.11,	8.2,],
['E231',	1.214,	45.6,	20.7,	85.3,	0.48,	0.8562,	14,	21.7,	0.39,	9.4,],
['E232',	1.239,	45.5,	20.6,	103,	0.45,	0.8719,	19,	29.3,	0.49,	9.4,],
['E233',	1.274,	45.5,	20.1,	116,	0.29,	0.8748,	23.7,	35.2,	0.8,	9.5,],
['E234',	1.296,	45.4,	20.3,	131,	0.22,	0.8802,	29.6,	42,	0.97,	9.4,],
['E241',	1.215,	45.7,	29.7,	85.6,	0.48,	0.8642,	16.6,	28.9,	0.4,	10.4,],
['E242',	1.243,	46.3,	29.6,	100,	0.42,	0.8712,	21.3,	35.9,	0.59,	10.5,],
['E243',	1.272,	45.9,	29.4,	115.2,	0.35,	0.8818,	26.2,	42.9,	0.78,	10.3,],
['E244',	1.302,	45.6,	30.2,	130.4,	0.24,	0.8922,	32.2,	51,	0.98,	10.2,],
['E311',	1.235,	88.5,	2.1,	85.6,	0.43,	0.8535,	19.6,	12.4,	0.58,	7.7,],
['E312',	1.262,	89.2,	2,	100,	0.34,	0.8642,	26.2,	17,	1.04,	7.8,],
['E313',	1.289,	89.1,	3.7,	116,	0.32,	0.879,	36.4,	22.5,	1.31,	7.8,],
['E314',	1.321,	88.8,	2.3,	131.2,	0.2,	0.8837,	44.3,	27.2,	2.12,	7.6,],
['E321',	1.236,	89.6,	12.4,	85.6,	0.5,	0.8655,	28.5,	18,	0.65,	8.7,],
['E322',	1.265,	90.6,	12.4,	100,	0.41,	0.8743,	33.8,	25.5,	0.87,	8.9,],
['E323',	1.293,	90,	12.1,	114.4,	0.32,	0.884,	41.6,	31.5,	1.33,	8.9,],
['E324',	1.321,	89.6,	12.4,	130.4,	0.22,	0.8955,	50.4,	36.9,	1.79,	8.7,],
['E331',	1.239,	89.1,	20.8,	85.6,	0.54,	0.8734,	31,	27.1,	0.56,	9.6,],
['E332',	1.269,	88.9,	20.7,	100,	0.39,	0.8835,	38.2,	32.8,	0.87,	9.8,],
['E333',	1.295,	88.5,	21.1,	116,	0.35,	0.8963,	46.1,	39.8,	0.98,	9.4,],
['E334',	1.322,	88.7,	21,	130,	0.27,	0.9043,	54.1,	46.1,	1.26,	9.3,],
['E341',	1.244,	87.9,	29,	84.8,	0.5,	0.8826,	33.7,	33,	0.66,	10.7,],
['E342',	1.271,	89.9,	30.7,	100.8,	0.42,	0.894,	42.6,	39.8,	0.89,	10.6,],
['E343',	1.309,	89.3,	29.8,	115.2,	0.37,	0.9028,	49.2,	46.6,	1.08,	10.2,],
['E344',	1.327,	89.6,	31,	130.4,	0.23,	0.9125,	57.7,	53.3,	1.46,	10.2,],
['E411',	1.26,	135.2,	3.3,	84.8,	0.5,	0.8728,	37.3,	18.1,	0.87,	8.6,],
['E412',	1.289,	136.6,	2.3,	102,	0.39,	0.8852,	47.6,	23,	1.46,	8.5,],
['E413',	1.318,	132.5,	4.4,	115.2,	0.28,	0.8988,	57.6,	27,	1.89,	8.5,],
['E414',	1.337,	116,	3.65,	130.4,	0.21,	0.9035,	60.7,	30.5,	2.57,	7.9,],
['E421',	1.261,	132.8,	11.7,	84.8,	0.5,	0.8827,	43.6,	23.9,	0.83,	9.5,],
['E422',	1.291,	135,	12.6,	100,	0.42,	0.8933,	54,	29.9,	1.34,	9.3,],
['E423',	1.32,	132.5,	11,	115,	0.29,	0.9039,	61.8,	35.7,	1.81,	9.1,],
['E424',	1.34,	115.8,	12,	130.2,	0.21,	0.9126,	66.8,	39.5,	2.1,	8.6,],
['E431',	1.265,	131.8,	20.4,	85.4,	0.53,	0.8904,	48.7,	30.3,	0.89,	10.1,],
['E432',	1.293,	131.3,	20,	100.8,	0.42,	0.9022,	57.3,	36.3,	1.35,	10.1,],
['E433',	1.32,	132.8,	20.6,	116,	0.36,	0.9199,	67.3,	43.4,	1.46,	9.6,],
['E434',	1.342,	115.8,	20.8,	129.6,	0.22,	0.9205,	69,	48.1,	1.8,	9.2,],
['E441',	1.267,	130.2,	28.7,	85.2,	0.51,	0.9014,	52.5,	37.4,	0.99,	10.9,],
['E442',	1.297,	131,	28.9,	100.8,	0.41,	0.9139,	61.2,	44,	1.37,	10.8,],
['E443',	1.325,	135.5,	28,	115.2,	0.34,	0.9237,	70.1,	51.2,	1.66,	10.4,],
['E444',	1.344,	115.8,	28.8,	129.6,	0.23,	0.9272,	71.3,	55.9,	1.72,	9.9,],
['REF1',	1.265,	67.2,	15.5,	107.2,	0.36,	0.8735,	29.2,	29.3,	0.8,	9,],
['REF2',	1.267,	66.6,	15.6,	107.2,	0.33,	0.8748,	28.9,	29.1,	0.85,	9,],
]

# %% [markdown]
# # dataset lines

# %%
data1=[]
for i in range(len(pur_wash_data)):
    data1.append([pur_wash_data[i][0], pur_wash_data[i][2], pur_wash_data[i][3], pur_wash_data[i][4]])
    data1.append([pur_wash_data[i][0], pur_wash_data[i][7], pur_wash_data[i][8], pur_wash_data[i][9]])
data1=pd.DataFrame(data=data1 ,columns = ["exp", "P2O5", 'HCl', 'Ca'])

# %%
data1[:5]
# Out:
#     exp  P2O5   HCl      Ca
# 0  P111  2.00  2.20   2.110
# 1  P111  0.08  0.10   0.041
# 2  P112  2.00  2.20  20.800
# 3  P112  0.10  0.29   0.010
# 4  P113  2.00  2.20  39.600

# %%
data2=[]
for i in range(len(extr_data)):
    data2.append([extr_data[i][0], extr_data[i][2], extr_data[i][3], extr_data[i][4]])
    data2.append([extr_data[i][0], extr_data[i][7], extr_data[i][8], extr_data[i][9]])
data2=pd.DataFrame(data=data2 ,columns = ["exp", "P2O5", 'HCl', 'Ca'])

# %%
fig1 = px.line_3d(data1, x='P2O5', y='HCl', z='Ca', color='exp')
fig1.update_layout(scene_aspectmode='cube')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.line_3d(data2, x='P2O5', y='HCl', z='Ca', color='exp')
fig2.update_layout(scene_aspectmode='cube')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # dataset equilibrium

# %%
data_washing1=pd.DataFrame(pur_wash_data, columns=['exp', 'density_aq',	'P2O5_aq',	'HCl_aq',	'Ca_aq',	'solvent_aq',	'density_org',	'P2O5_org',	'HCl_org',	'Ca_org',	'water_org'])
data_washing1
# Out:
#      exp  density_aq  P2O5_aq  HCl_aq  Ca_aq  solvent_aq  density_org  \
# 0   P111       1.030     2.00     2.2   2.11        2.60       0.8333
# 1   P112       1.039     2.00     2.2  20.80        1.50       0.8315
# 2   P113       1.083     2.00     2.2  39.60        1.00       0.8231
# 3   P114       1.123     2.20     2.2  60.40        0.68       0.8281
# 4   P121       1.015     1.95    30.4   2.06        2.40       0.8373
# ..   ...         ...      ...     ...    ...         ...          ...
# 61  P442       1.236   240.00    89.8  19.20        1.40       0.9546
# 62  P443       1.273   240.50    89.2  39.20        1.20       0.9659
# 63  P444       1.308   238.70    88.3  58.40        1.50       0.9766
# 64  REF1       1.161   121.40    44.2  28.40        1.30       0.8736
# 65  REF2       1.159   120.70    44.9  30.00        1.30       0.8710
#
#     P2O5_org  HCl_org  Ca_org  water_org
# 0       0.08     0.10   0.041       8.90
# 1       0.10     0.29   0.010       8.35
# ...

# %%
fig3 = make_subplots(rows=3, cols=2, subplot_titles=('P2O5_org','water_org','solvent_aq','HCl_org','Ca_org'), column_widths=[0.5, 0.5], vertical_spacing=0.05,
                     specs=[[{"type": "scene"}, {"type": "scene"}],[{"type": "scene"}, {"type": "scene"}],[{"type": "scene"}, {"type": "scene"}]])
plot_data=data_washing1.copy()
fig3.add_trace(go.Scatter3d(x=plot_data.P2O5_aq, y=plot_data.HCl_aq, z=plot_data.Ca_aq, marker_color=plot_data.P2O5_org, marker_symbol='circle', mode='markers', name='P2O5_org', text=plot_data.exp), 1, 1)
fig3.add_trace(go.Scatter3d(x=plot_data.P2O5_aq, y=plot_data.HCl_aq, z=plot_data.Ca_aq, marker_color=plot_data.water_org, marker_symbol='circle', mode='markers', name='water_org', text=plot_data.exp), 1, 2)
fig3.add_trace(go.Scatter3d(x=plot_data.P2O5_aq, y=plot_data.HCl_aq, z=plot_data.Ca_aq, marker_color=plot_data.solvent_aq, marker_symbol='circle', mode='markers', name='solvent_aq', text=plot_data.exp), 2, 1)
fig3.add_trace(go.Scatter3d(x=plot_data.P2O5_aq, y=plot_data.HCl_aq, z=plot_data.Ca_aq, marker_color=plot_data.HCl_org, marker_symbol='circle', mode='markers', name='HCl_org', text=plot_data.exp), 2, 2)
fig3.add_trace(go.Scatter3d(x=plot_data.P2O5_aq, y=plot_data.HCl_aq, z=plot_data.Ca_aq, marker_color=plot_data.Ca_org, marker_symbol='circle', mode='markers', name='Ca_org', text=plot_data.exp), 3, 1)

fig3.update_layout(title='', autosize=True,
                  width=810, height=800,
                  margin=dict(l=0, r=0, b=0, t=30),

                  )

fig3.update_layout(
    # scene1_zaxis_range=[0,10],
    # scene2_zaxis_range=[8,14],
    # scene3_zaxis_range=[0,3],
    # scene4_zaxis_range=[0,.1],
    )

# fig3.update_scenes(xaxis_title='H3PO4_aq', yaxis_title='SO4_aq', camera_eye=dict(x=1.5, y=1.5, z=1.5))
fig3.update_scenes(xaxis_title='P2O5_aq', yaxis_title='HCl_aq', zaxis_title='Ca_aq', camera_eye=dict(x=-0.0001, y=-1.5, z=-0.0001))
fig3.update_scenes(camera_projection_type="orthographic")
fig3.update_scenes(aspectmode='cube')

fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# אפשר לנסות להפוך את הגרפים למשטחים, כמו שעשיתי בבדיקה עבור ערן
