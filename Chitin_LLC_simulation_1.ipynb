# %% [markdown]
# <a href="https://colab.research.google.com/github/vladgap/LLC/blob/main/Chitin_LLC_simulation_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing

# %%
pip install MLNN
# Out:
# Requirement already satisfied: MLNN in /usr/local/lib/python3.10/dist-packages (2.2)

# %%
from MLNN import*

# %% [markdown]
# # EQUIL data

# %%
class EQUIL_chitin_1: # Br- only, no solvents dissolution
# gets xout [%solvent_aq, %Br_aq]
# calc xout , yout [%water_org, %Br_org]

    def __init__(self, x):
        x=np.array(x, dtype=float) # [[%solv, %Br], [%solv, %Br], [%solv, %Br], ...]
        y=np.zeros_like(x)
        y[:,0]=3 # constant water
        # 1/D = A*aq+B
        A, B = -0.2121, 11.89
        y[:,1] = x[:,1]/(A*x[:,1]+B) # %Br_org

        self.xout = x # [[%solvent_aq, %Br_aq], ...]
        self.yout = y # [[%water_org, %Br_org], ...]

# %%
import LLC_4_3 as LLC

# %% [markdown]
# # Cases

# %% [markdown]
# ## Extraction 1

# %%
EQUIL_chitin_1([[0,32.4]]).yout
# Out:
# array([[3.        , 6.45680715]])

# %%
test=LLC.Stage(5,1,[0,0],[0,39],EQUIL=EQUIL_chitin_1, convergence=1e-5)
test.output()
# Out:
# Oout= 5.38988100398262
# yout= [3.         4.23355759]
# yout_tag= [3.         4.23355759]  %water_org_equilib, %solubles_equilib
# Aout= 0.6101189960173794
# xout= [ 0.         26.52194712]
# equilibrium efficiency= [1. 1.]
# error= [7.03931588e-08 3.70836654e-06]
# convergence= [ 9.40479216e-06 -3.18208333e-06]

# %%
bat1_1=LLC.Battery(stages_num=5, Oin=7.895/1.806, Ain=1, yin=[0,0], xin=[0,39], eff=0.2, EQUIL= EQUIL_chitin_1)
bat1_1.runs
# Out:
# 18

# %%
table1_1=LLC.BatteryTable(bat1_1).data
# Out:
#                    Stage 1    Stage 2    Stage 3    Stage 4    Stage 5
# Org in, ton/hr    4.371539   4.552196   4.586437   4.623802   4.666285
# y1 in, %          0.000000   3.000000   3.000000   3.000000   3.000000
# y2 in, %          0.000000   0.968640   1.685592   2.455835   3.316633
# Aq in, ton/hr     0.834978   0.869187   0.906514   0.948963   1.000000
# x1 in, %          0.000000   0.000000   0.000000   0.000000   0.000000
# x2 in, %         27.538290  30.272091  33.019646  35.881408  39.000000
# Org out, ton/hr   4.552188   4.586423   4.623780   4.666260   4.717328
# y1 out, %         3.000000   3.000000   3.000000   3.000000   3.000000
# y2 out, %         0.968473   1.685298   2.455362   3.316054   4.330133
# Aq out, ton/hr    0.654329   0.834960   0.869171   0.906504   0.948957
# x1 out, %         0.000000   0.000000   0.000000   0.000000   0.000000
# x2 out, %        28.403478  27.536728  30.270877  33.018952  35.881025

# %%
bat=bat1_1
fig1_1 = go.Figure()
n=1 #Br
fig1_1.add_trace(go.Scatter(x=bat.xout_list[:,n], y=bat.yout_tag_list[:,n], name='Equilibrium', marker_color='black'))
fig1_1.add_trace(go.Scatter(x=bat.xout_list[:,n], y=bat.yout_list[:,n], name='Efficiency', marker_color='blue'))
fig1_1.add_trace(go.Scatter(x=np.concatenate((bat.xout_list[:,n], [bat.xin_list[-1,n]])), y=np.concatenate((bat.yin_list[:,n], [bat.yout_list[-1,n]])), mode = "markers+lines+text",
                          text= ['({:.1f},{:.2f})'.format(a,b) for a,b in zip(np.concatenate((bat.xout_list[:,n], [bat.xin_list[-1,n]])),np.concatenate((bat.yin_list[:,n], [bat.yout_list[-1,n]])))],
                          textposition ='top center', name='Operation', marker_color='green'))
fig1_1.update_xaxes(title_text="x, %")#, range=[0,40])
fig1_1.update_yaxes(title_text="y, %")#, range=[0,10])
# fig1_1.update_layout(title='', width=1200, height=600,)
fig1_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6cfe80e9-afda-4494-b066-8c510aa1284c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cfe80e9-afda-4494-b066-8c510aa1284c")) {                    Plotly.newPlot(                        "6cfe80e9-afda-4494-b066-8c510aa1284c",                        [{"marker":{"color":"black"},"name":"Equilibrium","x":[28.403477845406655,27.536727889293356,30.27087731271451,33.018952430172206,35.88102498949606],"y":[4.842363888343593,4.551931548017013,5.534439642725227,6.756929274952623,8.384132839700264],"type":"scatter"},{"marker":{"color":"blue"},"name":"Efficiency","x":[28.403477845406655,27.536727889293356,30.27087731271451,33.018952430172206,35.88102498949606],"y":[0.9684727776687186,1.685298048352796,2.4553619245318723,3.316054132340172,4.330132982987526],"type":"scatter"},{"marker":{"color":"green"},"mode":"markers+lines+text","name":"Operation","text":["(28.4,0.00)","(27.5,0.97)","(30.3,1.69)","(33.0,2.46)","(35.9,3.32)","(39.0,4.33)"],"textposition":"top center","x":[28.403477845406655,27.536727889293356,30.27087731271451,33.018952430172206,35.88102498949606,39.0],"y":[0.0,0.9686396734367415,1.685592494983534,2.455835346687059,3.3166330188093416,4.330132982987526],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinew ...

# %% [markdown]
# ## Extraction 2

# %%
bat1_2=LLC.Battery(stages_num=5, Oin=7.895/1.806, Ain=1, yin=[0,0], xin=[0,39], eff=1, EQUIL= EQUIL_chitin_1)
bat1_2.runs
# Out:
# 37

# %%
table1_2=LLC.BatteryTable(bat1_2).data
# Out:
#                    Stage 1    Stage 2    Stage 3    Stage 4    Stage 5
# Org in, ton/hr    4.371539   4.578236   4.623402   4.671881   4.733805
# y1 in, %          0.000000   3.000000   3.000000   3.000000   3.000000
# y2 in, %          0.000000   1.514926   2.447752   3.428992   4.653538
# Aq in, ton/hr     0.745130   0.790267   0.838745   0.900640   1.000000
# x1 in, %          0.000000   0.000000   0.000000   0.000000   0.000000
# x2 in, %         19.157704  23.603873  27.846069  32.601243  39.000000
# Org out, ton/hr   4.578236   4.623388   4.671881   4.733788   4.833165
# y1 out, %         3.000000   3.000000   3.000000   3.000000   3.000000
# y2 out, %         1.514926   2.447454   3.428992   4.653195   6.552650
# Aq out, ton/hr    0.538433   0.745115   0.790267   0.838733   0.900640
# x1 out, %         0.000000   0.000000   0.000000   0.000000   0.000000
# x2 out, %        13.632224  19.156166  23.603873  27.845034  32.601243

# %%
# Extraction efficiency
bat=bat1_2
eff=bat.Oout*bat.yout[1]/(bat.Ain*bat.xin[1])
print ('Extraction efficiency = {:.1%}'.format(eff))
# Out:
# Extraction efficiency = 81.2%

# %%
bat=bat1_2
fig1_2 = go.Figure()
n=1 #Br
fig1_2.add_trace(go.Scatter(x=bat.xout_list[:,n], y=bat.yout_tag_list[:,n], name='Equilibrium', marker_color='black'))
fig1_2.add_trace(go.Scatter(x=bat.xout_list[:,n], y=bat.yout_list[:,n], name='Efficiency', marker_color='blue'))
fig1_2.add_trace(go.Scatter(x=np.concatenate((bat.xout_list[:,n], [bat.xin_list[-1,n]])), y=np.concatenate((bat.yin_list[:,n], [bat.yout_list[-1,n]])), mode = "markers+lines+text",
                          text= ['({:.1f},{:.2f})'.format(a,b) for a,b in zip(np.concatenate((bat.xout_list[:,n], [bat.xin_list[-1,n]])),np.concatenate((bat.yin_list[:,n], [bat.yout_list[-1,n]])))],
                          textposition ='top center', name='Operation', marker_color='green'))
fig1_2.update_xaxes(title_text="x, %")#, range=[0,40])
fig1_2.update_yaxes(title_text="y, %")#, range=[0,10])
# fig1_2.update_layout(title='', width=1200, height=600,)
fig1_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e019c8d-7f9d-447a-b52f-395dd4fb63e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e019c8d-7f9d-447a-b52f-395dd4fb63e1")) {                    Plotly.newPlot(                        "3e019c8d-7f9d-447a-b52f-395dd4fb63e1",                        [{"marker":{"color":"black"},"name":"Equilibrium","x":[13.632224384999137,19.156166353691358,23.603873257797126,27.845034499252257,32.601243071885165],"y":[1.5149263769198444,2.4474539875167145,3.4289920801750102,4.653194724570907,6.552649705223246],"type":"scatter"},{"marker":{"color":"blue"},"name":"Efficiency","x":[13.632224384999137,19.156166353691358,23.603873257797126,27.845034499252257,32.601243071885165],"y":[1.5149263769198444,2.4474539875167145,3.4289920801750102,4.653194724570907,6.552649705223246],"type":"scatter"},{"marker":{"color":"green"},"mode":"markers+lines+text","name":"Operation","text":["(13.6,0.00)","(19.2,1.51)","(23.6,2.45)","(27.8,3.43)","(32.6,4.65)","(39.0,6.55)"],"textposition":"top center","x":[13.632224384999137,19.156166353691358,23.603873257797126,27.845034499252257,32.601243071885165,39.0],"y":[0.0,1.514926388616685,2.4477524470655183,3.4289921014996465,4.653538253062891,6.552649705223246],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar": ...
